# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(credential=DefaultAzureCredential())
# Out:
# Found the config file in: C:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\config.json
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %%
mlflow_tracking_uri = ml_client.workspaces.get(ml_client.workspace_name).mlflow_tracking_uri
# Out:
# Exception in thread Thread-14 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\Joe\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\Joe\AppData\Local\Programs\Python\Python310\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Joe\AppData\Local\Programs\Python\Python310\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
#   File "C:\Users\Joe\AppData\Local\Programs\Python\Python310\lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 271: character maps to <undefined>
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mlflow_tracking_uri = ml_client.workspaces.get(ml_client.workspace_name).mlflow_tracking_uri
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\ai\ml\_telemetry\activity.py:288, in monitor_with_activity.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     284     with tracer.start_as_current_span(ACTIVITY_SPAN):
#     285         with log_activity(
#     286             logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions
#     287         ):
# --> 288             return f(*args, **kwargs)
#     289 elif hasattr(logger, "package_logger"):
#     290     with log_activity(logger.package_logger, activity_name or f.__name__, activity_type, custom_dimensions):
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\tracing\decorator.py:116, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     114 for key, value in func_tracing_attributes.items():
#     115     span.add_attribute(key, value)
# --> 116 return func(*args, **kwargs)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\ai\ml\operations\_workspace_operations.py:141, in WorkspaceOperations.get(self, name, **kwargs)
#     120 @monitor_with_activity(ops_logger, "Workspace.Get", ActivityType.PUBLICAPI)
#     121 @distributed_trace
#     122 # pylint: disable=arguments-renamed
#     123 def get(self, name: Optional[str] = None, **kwargs: Dict) -> Optional[Workspace]:
#     124     """Get a Workspace by name.
#     125
#     126     :param name: Name of the workspace.
#    (...)
#     138             :caption: Get the workspace with the given name.
#     139     """
# --> 141     return super().get(workspace_name=name, **kwargs)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\ai\ml\operations\_workspace_operations_base.py:89, in WorkspaceOperationsBase.get(self, workspace_name, **kwargs)
#      87 workspace_name = self._check_workspace_name(workspace_name)
#      88 resource_group = kwargs.get("resource_group") or self._resource_group_name
# ---> 89 obj = self._operation.get(resource_group, workspace_name)
#      90 v2_service_context = {}
#      92 v2_service_context["subscription_id"] = self._subscription_id
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\tracing\decorator.py:116, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     114 for key, value in func_tracing_attributes.items():
#     115     span.add_attribute(key, value)
# --> 116 return func(*args, **kwargs)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\ai\ml\_restclient\v2024_10_01_preview\operations\_workspaces_operations.py:947, in WorkspacesOperations.get(self, resource_group_name, workspace_name, **kwargs)
#     944 request = _convert_request(request)
#     945 request.url = self._client.format_url(request.url)
# --> 947 pipeline_response = self._client._pipeline.run(  # pylint: disable=protected-access
#     948     request,
#     949     stream=False,
#     950     **kwargs
#     951 )
#     952 response = pipeline_response.http_response
#     954 if response.status_code not in [200]:
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\_base.py:240, in Pipeline.run(self, request, **kwargs)
#     238 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     239 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 240 return first_node.send(pipeline_request)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 96 (2 times)]
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\_base.py:96, in _SansIOHTTPPolicyRunner.send(self, request)
#      94 _await_result(self._policy.on_request, request)
#      95 try:
# ---> 96     response = self.next.send(request)
#      97 except Exception:
#      98     _await_result(self._policy.on_exception, request)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\mgmt\core\policies\_base.py:95, in ARMAutoResourceProviderRegistrationPolicy.send(self, request)
#      93 def send(self, request: PipelineRequest[HTTPRequestType]) -> PipelineResponse[HTTPRequestType, HTTPResponseType]:
#      94     http_request = request.http_request
# ---> 95     response = self.next.send(request)
#      96     if response.http_response.status_code == 409:
#      97         rp_name = self._check_rp_not_registered_err(response)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\policies\_redirect.py:204, in RedirectPolicy.send(self, request)
#     202 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     203 while retryable:
# --> 204     response = self.next.send(request)
#     205     redirect_location = self.get_redirect_location(response)
#     206     if redirect_location and redirect_settings["allow"]:
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\policies\_retry.py:551, in RetryPolicy.send(self, request)
#     549 self._configure_timeout(request, absolute_timeout, is_response_error)
#     550 request.context["retry_count"] = len(retry_settings["history"])
# --> 551 response = self.next.send(request)
#     552 if self.is_retry(retry_settings, response):
#     553     retry_active = self.increment(retry_settings, response=response)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\policies\_authentication.py:157, in BearerTokenCredentialPolicy.send(self, request)
#     149 def send(self, request: PipelineRequest[HTTPRequestType]) -> PipelineResponse[HTTPRequestType, HTTPResponseType]:
#     150     """Authorize request with a bearer token and send it to the next policy
#     151
#     152     :param request: The pipeline request object
#    (...)
#     155     :rtype: ~azure.core.pipeline.PipelineResponse
#     156     """
# --> 157     self.on_request(request)
#     158     try:
#     159         response = self.next.send(request)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\policies\_authentication.py:132, in BearerTokenCredentialPolicy.on_request(self, request)
#     129 self._enforce_https(request)
#     131 if self._token is None or self._need_new_token:
# --> 132     self._request_token(*self._scopes)
#     133 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     134 self._update_headers(request.http_request.headers, bearer_token)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\policies\_authentication.py:108, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     101 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     102     """Request a new token from the credential.
#     103
#     104     This will call the credential's appropriate method to get a token and store it in the policy.
#     105
#     106     :param str scopes: The type of access needed.
#     107     """
# --> 108     self._token = self._get_token(*scopes, **kwargs)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\core\pipeline\policies\_authentication.py:98, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      95         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#      96             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# ---> 98     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#      99 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\identity\_credentials\default.py:256, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     253     return token_info
#     255 within_dac.set(True)
# --> 256 token_info = cast(SupportsTokenInfo, super()).get_token_info(*scopes, options=options)
#     257 within_dac.set(False)
#     258 return token_info
#
# File c:\Users\Joe\Documents\FHSWF\3. Semester\MLOPS\MLOPS_Einkommensvorhersage\lib\site-packages\azure\identity\_credentials\chained.py:219, in ChainedTokenCredential.get_token_info(self, options, *scopes)
#     211 message = (
#     212     self.__class__.__name__
#     213     + " failed to retrieve a token from the included credentials."
#    (...)
#     216     "https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot."
#     217 )
#     218 _LOGGER.warning(message)
# --> 219 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	AzureCliCredential: Azure CLI not found on path
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
